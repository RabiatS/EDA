# %% [markdown]
# <a href="https://colab.research.google.com/github/RabiatS/EDA/blob/Netflix_dataset1/Netflix_dataset.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !kaggle datasets download -d danghuutri/netflix-movies
# Out:
# Dataset URL: https://www.kaggle.com/datasets/danghuutri/netflix-movies
# License(s): MIT
# ...
#   0% 0.00/371k [00:00<?, ?B/s]
# 100% 371k/371k [00:00<00:00, 28.8MB/s]

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

data = pd.read_csv("netflix-movies.zip")
df = pd.DataFrame(data)

df.sample(10)
df.describe()
df.head()
# Out:
#          id   type                          name creator  \
# 0  81416533  Movie                Heart of Stone     NaN
# 1  80991406  Movie  Johnny English Strikes Again     NaN
# 2  81644420  Movie                          Hunt     NaN
# 3  70208104  Movie                    Safe House     NaN
# 4  70297761  Movie                    Commitment     NaN
#
#                                          starring  year rating     time  \
# 0             Gal Gadot, Jamie Dornan, Alia Bhatt  2023  TV-PG  125 min
# 1       Rowan Atkinson, Ben Miller, Emma Thompson  2018  TV-PG   88 min
# 2       Lee Jung-jae, Jung Woo-sung, Jeon Hye-jin  2022  TV-14  125 min
# 3  Denzel Washington, Ryan Reynolds, Vera Farmiga  2012  TV-14  114 min
# 4        Choi Seung-hyun, Han Ye-ri, Yoon Je-moon  2013  TV-14  112 min
#
#                                               genres        country  \
# 0  Drama Movies ,Action & Adventure Movies ,Spy M...  United States
# ...

# %%
# Number of shows and movies per year

df.groupby(['year', 'type']).size().unstack().plot(kind='bar')
# Out:
# <Axes: xlabel='year'>

# %%
from matplotlib import pyplot as plt
import seaborn as sns
_df_5.groupby('time').size().plot(kind='barh', color=sns.palettes.mpl_palette('Dark2'))
plt.gca().spines[['top', 'right',]].set_visible(False)

# %%
from matplotlib import pyplot as plt
_df_12['year'].plot(kind='line', figsize=(8, 4), title='year')
plt.gca().spines[['top', 'right']].set_visible(False)
